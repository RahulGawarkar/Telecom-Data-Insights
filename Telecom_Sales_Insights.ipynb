# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Load the dataset
file_path = 'Expanded_Dataset.csv'
df = pd.read_csv(file_path)

# Display basic information about the dataset
print("Dataset Overview:")
display(df.head())
print("\nDataset Info:")
df.info()

# Checking for missing values
print("\nMissing Values:")
print(df.isnull().sum())

# Basic statistics
print("\nStatistical Summary:")
display(df.describe())

# Visualization 1: Histogram of a numeric column (example: 'Column_Name')
plt.figure(figsize=(8,5))
sns.histplot(df['Units Sold'], bins=30, kde=True, color='blue')
plt.title('Distribution of Column_Name')
plt.xlabel('Column_Name')
plt.ylabel('Frequency')
plt.show()

# Visualization 2: Pie chart for categorical data (example: 'Category_Column')
plt.figure(figsize=(6,6))
df['5G Capability'].value_counts().plot.pie(autopct='%1.1f%%', cmap='coolwarm', startangle=90)
plt.title('Category Distribution')
plt.ylabel('')
plt.show()

# Select only numeric columns
numeric_df = df.select_dtypes(include=['number'])

# Plot the correlation heatmap
plt.figure(figsize=(10,6))
sns.heatmap(numeric_df.corr(), annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Heatmap')
plt.show()


# Conclusion
print("Analysis Complete. Insights should be derived based on the specific dataset features.")
# Out:
# Dataset Overview:
#    Year Quarter  Product Model 5G Capability  Units Sold   Revenue ($)  \
# 0  2019      Q1     Galaxy S10            No       26396  4.212951e+06
# 1  2019      Q1  Galaxy Note10            No       25671  7.240266e+06
# 2  2019      Q1     Galaxy S20            No       16573  2.560833e+07
# 3  2019      Q1  Galaxy Note20            No        7177  2.198442e+07
# 4  2019      Q1     Galaxy S21            No       45633  1.634244e+07
#
#    Market Share (%)  Regional 5G Coverage (%)  5G Subscribers (millions)  \
# 0              1.04                     57.36                      39.55
# 1              2.82                     85.80                      42.58
# 2             -0.03                     47.02                       3.78
# 3              0.84                     25.70                      23.41
# 4              2.36                     89.13                      44.43
#
#    Avg 5G Speed (Mbps)  Preference for 5G (%)                Region
# ...
